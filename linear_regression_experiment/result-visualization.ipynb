# %%
import time
import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter('ignore')

from collections import OrderedDict
import functools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
# use ggplot styles for graphs
plt.style.use('ggplot')


import arviz as az

# %%
import ot
import tensorflow as tf
import tensorflow_probability as tfp

# set tf logger to log level ERROR to avoid warnings
tf.get_logger().setLevel('ERROR')

tfd = tfp.distributions
tfb = tfp.bijectors
tfk = tf.keras

# %% [markdown]
# # Load Linear Regression Experiment Results

# %%
import pickle

# %%
with open('./linear_regression_exp_results.pickle', 'rb') as handle:
    results = pickle.load(handle)
    
with open('./linear_regression_exp_results.pickle', 'wb') as handle:
    pickle.dump(results, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
results
# Out:
# {'dataset_1': {'data': {'targets': array([ -4.8898687 ,  15.279532  ,   9.4580555 , -10.033951  ,
#           -10.9237175 ,   8.850783  ,   0.49539566,  13.63727   ,
#            10.419363  ,   3.6100407 ,  -1.0401444 ,   8.00333   ,
#            17.49944   ,  16.847786  ,  26.286295  ,  -3.3038898 ,
#           -13.782696  , -11.645771  ,   7.4033    ,  11.389244  ,
#             1.9222739 ,   0.31073856,   3.656439  ,  -0.07514167,
#             1.9197718 ,  12.397112  ,  -0.40173602, -14.855106  ,
#            16.396084  ,   8.403273  ,   0.7387252 ,   8.346368  ,
#             5.6071367 ,   5.6372967 ,   1.7029344 ,  -7.879801  ,
#           -11.847522  ,  -3.450976  ,   2.9607034 ,  -2.859723  ,
#             2.02604   ,  -7.3506985 ,   4.91314   ,  -2.8731723 ,
#            -2.1879244 ,  28.766483  ,   6.2844048 ,   2.1923232 ,
#            -0.4363854 ,  10.722111  ], dtype=float32),
#    'true_params': OrderedDict([('loc', 3.0), ('scale', 9.0)])},
# ...
